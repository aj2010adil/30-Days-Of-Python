# %% [markdown]
# <a href="https://colab.research.google.com/github/aj2010adil/30-Days-Of-Python/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from airflow import DAG
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a6c1cd2be4ba> in <module>()
# ----> 1 from airflow import DAG
#
# ModuleNotFoundError: No module named 'airflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install apache-airflow
pip install psycopg2-binary

# %%
import threading as t

def hh():
  print(t.Thread.name.getter)
  print("hhhhh")



i=t.Thread(target=hh,name="gy")
i.start()

hh()
# Out:
# <built-in method getter of property object at 0x7f43aa68c6b0>
# hhhhh
# <built-in method getter of property object at 0x7f43aa68c6b0>
# hhhhh

# %%
import os
import threading

# a simple function that wastes CPU cycles forever
def cpu_waster():
    while True:
        pass

# display information about this process
print('\n  Process ID: ', os.getpid())
print('Thread Count: ', threading.active_count())
for thread in threading.enumerate():
    print(thread)

print('\nStarting 12 CPU Wasters...')
for i in range(12):
    threading.Thread(target=cpu_waster).start()

# display information about this process
print('\n  Process ID: ', os.getpid())
print('Thread Count: ', threading.active_count())
for thread in threading.enumerate():
    print(thread)
# Out:
#   Process ID:  64
# Thread Count:  9
# <_MainThread(MainThread, started 139928637568896)>
# <Thread(Thread-2, started daemon 139928127489792)>
# <Heartbeat(Thread-3, started daemon 139928119097088)>
# <ParentPollerUnix(Thread-1, started daemon 139928053962496)>
# <WriterThread(pydevd.Writer, started daemon 139928030631680)>
# <ReaderThread(pydevd.Reader, started daemon 139928022238976)>
# <PyDBCommandThread(pydevd.CommandThread, started daemon 139928013584128)>
# <_TimeoutThread(Thread-9, started daemon 139928005191424)>
# <CheckAliveThread(pydevd.CheckAliveThread, started 139927996798720)>
#
# Starting 12 CPU Wasters...
#
#   Process ID:  64
# Thread Count:  21
# <_MainThread(MainThread, started 139928637568896)>
# <Thread(Thread-2, started daemon 139928127489792)>
# <Heartbeat(Thread-3, started daemon 139928119097088)>
# <ParentPollerUnix(Thread-1, started daemon 139928053962496)>
# <WriterThread(pydevd.Writer, started daemon 139928030631680)>
# ...

# %% [markdown]
# # New Section

# %%
# %%sh
# airflow db init

# %% [markdown]
# %%sh
# ls

# %%
# %%sh
# airflow webserver
# Out:
# sh: 1: airflow: not found
